# %% [markdown]
# # "Getting started with julia"
# > "Awesome summary"
#
# - toc: true
# - branch: master
# - badges: true
# - comments: true
# - categories: [julia, jupyter]
# - image: https://github.com/JuliaLang/IJulia.jl/raw/master/deps/ijulialogo.png
# - hide: false
# - search_exclude: true
# - metadata_key1: metadata_value1
# - metadata_key2: metadata_value2

# %% [markdown]
# ## installing conda
#
# ## installing jupyter
#
# ## installing julia
#
# https://juliacomputing.com/products/juliapro/

# %%
1+1
# Out:
# 2
